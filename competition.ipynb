# %% [markdown]
# <p><strong>LOADING DATASET</strong></p>

# %%
import pandas as pd
import numpy as np

# %%
data_train = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')

# %% [markdown]
# <strong>GET INSIGHT OF DATA</strong>

# %%
data_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data_train.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data_train.shape
# Out:
# (1460, 81)

# %%
data_train.set_index('Id', inplace=True)#change the index to the Id column

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# <p> this data has 83 features(culunms) compose by 43  unnumerical data and 38 numerical  </p>

# %%
data_train.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %% [markdown]
# <p><strong>Exploratory Data Analysis<strong></p>

# %%
data_train.describe()
# we use the describe method to get the summary statistics of the numerical columns
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
#we use include='all' to get the summary statistics of all the columns
data_train.describe(include='all')
# Out:
#          MSSubClass MSZoning  LotFrontage        LotArea Street Alley  \
# count   1460.000000     1460  1201.000000    1460.000000   1460    91
# unique          NaN        5          NaN            NaN      2     2
# top             NaN       RL          NaN            NaN   Pave  Grvl
# freq            NaN     1151          NaN            NaN   1454    50
# mean      56.897260      NaN    70.049958   10516.828082    NaN   NaN
# std       42.300571      NaN    24.284752    9981.264932    NaN   NaN
# min       20.000000      NaN    21.000000    1300.000000    NaN   NaN
# 25%       20.000000      NaN    59.000000    7553.500000    NaN   NaN
# 50%       50.000000      NaN    69.000000    9478.500000    NaN   NaN
# 75%       70.000000      NaN    80.000000   11601.500000    NaN   NaN
# max      190.000000      NaN   313.000000  215245.000000    NaN   NaN
#
#        LotShape LandContour Utilities LotConfig  ...     PoolArea PoolQC  \
# ...

# %% [markdown]
# <p>some of the columns like "LOTFrontage, Alley, fence.... "have a lot of missing values, we will take care of that later</p>

# %%
numeric_features = data_train.select_dtypes(include=["number"])
categorical_features = data_train.select_dtypes(include=['object'])
#selecting the numerical and categorical features

# %% [markdown]
# NUMERICAL DATA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_train.hist(bins=30, figsize=(50,50))
# Out:
# array([[<Axes: title={'center': 'MSSubClass'}>,
#         <Axes: title={'center': 'LotFrontage'}>,
#         <Axes: title={'center': 'LotArea'}>,
#         <Axes: title={'center': 'OverallQual'}>,
#         <Axes: title={'center': 'OverallCond'}>,
#         <Axes: title={'center': 'YearBuilt'}>],
#        [<Axes: title={'center': 'YearRemodAdd'}>,
#         <Axes: title={'center': 'MasVnrArea'}>,
#         <Axes: title={'center': 'BsmtFinSF1'}>,
#         <Axes: title={'center': 'BsmtFinSF2'}>,
#         <Axes: title={'center': 'BsmtUnfSF'}>,
#         <Axes: title={'center': 'TotalBsmtSF'}>],
#        [<Axes: title={'center': '1stFlrSF'}>,
#         <Axes: title={'center': '2ndFlrSF'}>,
#         <Axes: title={'center': 'LowQualFinSF'}>,
#         <Axes: title={'center': 'GrLivArea'}>,
#         <Axes: title={'center': 'BsmtFullBath'}>,
#         <Axes: title={'center': 'BsmtHalfBath'}>],
#        [<Axes: title={'center': 'FullBath'}>,
# ...

# %%
numeric_features.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
col_n=5
row_n=numeric_features.shape[1]//col_n
fig, axs = plt.subplots(row_n, col_n, figsize=(50,50))
col_names = numeric_features.columns
for i in range(row_n):
    for j in range(col_n):
        sns.scatterplot( data=numeric_features,x=col_names[i*col_n+j], y='SalePrice', ax=axs[i,j])

# %%
fig, axs = plt.subplots(row_n, col_n, figsize=(30,30))
for i in range(row_n):
    for j in range(col_n):
        sns.boxplot( data=numeric_features, x=col_names[i*col_n+j], ax=axs[i,j])

# %% [markdown]
# <p>we can observe that there are many outliers in the dataset , so it's good to use standard normalization for scaling<br></p>

# %%
corr_matrix = numeric_features.corr()
corr_matrix["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# ...

# %%
plt.figure(figsize=(40,40))
sns.heatmap(corr_matrix, annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# <p>many features are correlated , we can consider reducing the dimension of dataset using PCA</p>

# %% [markdown]
# CATHEGORICAL FEATURE

# %%
categorical_features.describe()
#some of the categorical features have a lot of  missing values,we will drop them later
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
for col in categorical_features.columns:
    print(f'{col} : {categorical_features[col].unique()}')
    
#the unique values of the categorical features are hierarchically arranged in the order of their importance in the data, we will use ordinal encoding to encode them
# Out:
# MSZoning : ['RL' 'RM' 'C (all)' 'FV' 'RH']
# Street : ['Pave' 'Grvl']
# Alley : [nan 'Grvl' 'Pave']
# LotShape : ['Reg' 'IR1' 'IR2' 'IR3']
# LandContour : ['Lvl' 'Bnk' 'Low' 'HLS']
# Utilities : ['AllPub' 'NoSeWa']
# LotConfig : ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# LandSlope : ['Gtl' 'Mod' 'Sev']
# Neighborhood : ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# Condition1 : ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# Condition2 : ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# BldgType : ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# HouseStyle : ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# RoofStyle : ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# ...

# %%
for col in categorical_features.columns:
    print(f'{col} : {categorical_features[col].value_counts()}')
# Out:
# MSZoning : MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
# Street : Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64
# Alley : Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64
# LotShape : LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64
# LandContour : LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64
# Utilities : Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64
# LotConfig : LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64
# LandSlope : LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64
# Neighborhood : Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# ...

# %%
col_n=5
row_n=categorical_features.shape[1]//col_n
fig, axs = plt.subplots(row_n, col_n, figsize=(50,50))
col_names = categorical_features.columns
for i in range(row_n):
    for j in range(col_n):
        sns.countplot( data=categorical_features,x=col_names[i*col_n+j], hue=categorical_features[col_names[i*col_n+j]],palette="viridis",ax=axs[i,j],legend=False)

# %% [markdown]
# some cathegories are very rare

# %%
fig, axs = plt.subplots(row_n, col_n, figsize=(50,50))
for i in range(row_n):
    for j in range(col_n):
        sns.boxplot( data=categorical_features, x=col_names[i*col_n+j], y=data_train["SalePrice"],hue=categorical_features[col_names[i*col_n+j]],palette="viridis", ax=axs[i,j])

# %% [markdown]
# <strong>DATA PREPROCESSING</strong>

# %% [markdown]
# TRAITEMENT DES VALEURS MANQUANTES

# %%
#we will drop the columns with a lot of missing values
columns_to_drop = ['Alley','PoolQC','Fence','MiscFeature',"MasVnrType"]
categorical_features.drop(columns_to_drop, axis=1, inplace=True)

# %%
categorical_features.isnull().sum()[categorical_features.isnull().sum()>0]
# Out:
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# Electrical        1
# FireplaceQu     690
# GarageType       81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# dtype: int64

# %%
categorical_features["FireplaceQu"].fillna("unknow", inplace=True)#filling the missing values with unknow
# Out:
# C:\Users\T490s Ha\AppData\Local\Temp\ipykernel_2708\2818504127.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   categorical_features["FireplaceQu"].fillna("unknow", inplace=True)#filling the missing values with unknow

# %%
from sklearn.impute import SimpleImputer
imputer_cat = SimpleImputer(strategy="most_frequent")
categorical_features = pd.DataFrame(imputer_cat.fit_transform(categorical_features), columns=categorical_features.columns)#filling the missing values with the most frequent value

# %% [markdown]
# categorical data encoding

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
categorical_features_encoded = encoder.fit_transform(categorical_features)

# %%
numeric_features=numeric_features.drop("SalePrice", axis=1)
numeric_features.isnull().sum()[numeric_features.isnull().sum()>0]
# Out:
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# dtype: int64

# %%
inputer_num = SimpleImputer(strategy="median")
numeric_features = pd.DataFrame(inputer_num.fit_transform(numeric_features), columns=numeric_features.columns)#filling the missing values with the median value

# %%
numeric_features.isnull().sum()[numeric_features.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# SCALING AND PIPELINE CONSTRUCTION

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
numeric_features_scaled = pd.DataFrame(scaler.fit_transform(numeric_features), columns=numeric_features.columns)#scaling the numerical features

# %%
from sklearn.base import BaseEstimator, TransformerMixin
class DropColumns(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        X["FireplaceQu"].fillna("unknow", inplace=True)
        return X.drop(self.columns, axis=1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
num_pipeline = Pipeline([
    ('imputer_num', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])
cat_pipeline = Pipeline([
    ("DropColumns", DropColumns(columns_to_drop)),
    ('imputer_cat', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder())
])

# %%
num_columns = numeric_features.columns
cat_columns = data_train.select_dtypes(include=['object']).columns

# %%
num_cat_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_columns),
    ('cat', cat_pipeline, cat_columns)
])

# %%
X_train = data_train.drop("SalePrice", axis=1)
y_train = data_train["SalePrice"]

# %%
X_train_prepared = num_cat_pipeline.fit_transform(X_train)
# Out:
# C:\Users\T490s Ha\AppData\Local\Temp\ipykernel_2708\3511087348.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X["FireplaceQu"].fillna("unknow", inplace=True)

# %% [markdown]
# <strong>TRAINING MODELS</strong>

# %% [markdown]
# LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train_prepared, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
y_train_pred = lin_reg.predict(X_train_prepared)
lin_mse = mean_squared_error(y_train, y_train_pred)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# np.float64(20946.79400727243)

# %%
from sklearn.model_selection import cross_val_score
lin_scores = cross_val_score(lin_reg, X_train_prepared, y_train, scoring="neg_mean_squared_error", cv=5)
lin_rmse_scores = np.sqrt(-lin_scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

# %%
display_scores(lin_rmse_scores)
# Out:
# Scores: [28620.74520543 34237.94776874 37588.92509682 23784.14357671
#  46981.26825847]
# Mean: 34242.605981232606
# Standard deviation: 7930.3990364298315

# %% [markdown]
# DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor()
tree_reg.fit(X_train_prepared, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_train_pred = tree_reg.predict(X_train_prepared)
tree_mse = mean_squared_error(y_train, y_train_pred)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# np.float64(0.0)

# %%
tree_scores = cross_val_score(tree_reg, X_train_prepared, y_train, scoring="neg_mean_squared_error", cv=5)
tree_rmse_scores = np.sqrt(-tree_scores)
display_scores(tree_rmse_scores)
# Out:
# Scores: [40951.82961578 44421.56210917 34580.39916629 33066.54849465
#  52127.24022209]
# Mean: 41029.515921597886
# Standard deviation: 6923.459457765179

# %% [markdown]
# the model perform well on train set and poorly on validation set , that'is can be an overfiting

# %%
from sklearn.model_selection import learning_curve
train_sizes, train_scores, test_scores = learning_curve(
    tree_reg, X_train_prepared, y_train, scoring="neg_mean_squared_error", cv=5)
train_scores_mean = np.mean(np.sqrt(-train_scores), axis=1)
test_scores_mean = np.mean(np.sqrt(-test_scores), axis=1)

# %%
plt.plot(train_sizes, train_scores_mean, 'o-', color="r",label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g",label="Cross-validation score")
plt.xlabel("Train size")
plt.ylabel("RMSE")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(X_train_prepared, y_train)
# Out:
# RandomForestRegressor()

# %%
y_train_pred = forest_reg.predict(X_train_prepared)
forest_mse = mean_squared_error(y_train, y_train_pred)
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# np.float64(11569.732115295108)

# %%
forest_scores = cross_val_score(forest_reg, X_train_prepared, y_train, scoring="neg_mean_squared_error", cv=5)
forest_rmse_scores = np.sqrt(-forest_scores)
display_scores(forest_rmse_scores)
# Out:
# Scores: [26755.38405695 32004.29104946 30745.45343644 24876.12667226
#  36287.74924083]
# Mean: 30133.80089118731
# Standard deviation: 4019.969429152574

# %%
forest_sizes, forest_train_scores, forest_test_scores = learning_curve(forest_reg, X_train_prepared, y_train, scoring="neg_mean_squared_error", cv=5)
forest_train_scores_mean = np.mean(np.sqrt(-forest_train_scores), axis=1)
forest_test_scores_mean = np.mean(np.sqrt(-forest_test_scores), axis=1)

# %%
plt.plot(forest_sizes, forest_train_scores_mean, 'o-', color="r",label="Training score")
plt.plot(forest_sizes, forest_test_scores_mean, 'o-', color="g",label="Cross-validation score")
plt.xlabel("Train size")
plt.ylabel("RMSE")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVR
svm_reg = SVR()
svm_reg.fit(X_train_prepared, y_train)
# Out:
# SVR()

# %%
y_train_pred = svm_reg.predict(X_train_prepared)
svm_mse = mean_squared_error(y_train, y_train_pred)
svm_rmse = np.sqrt(svm_mse)
svm_rmse
# Out:
# np.float64(81351.76351344478)

# %%
svm_scores = cross_val_score(svm_reg, X_train_prepared, y_train, scoring="neg_mean_squared_error", cv=5)
svm_rmse_scores = np.sqrt(-svm_scores)
display_scores(svm_rmse_scores)
# Out:
# Scores: [76918.38834127 83451.78918706 89431.22272471 71705.79298368
#  84082.3855488 ]
# Mean: 81117.91575710075
# Standard deviation: 6157.4378549676785

# %%
svm_train_sizes, svm_train_scores, svm_test_scores = learning_curve(svm_reg, X_train_prepared, y_train, scoring="neg_mean_squared_error", cv=5)
svm_train_scores_mean = np.mean(np.sqrt(-svm_train_scores), axis=1)
svm_test_scores_mean = np.mean(np.sqrt(-svm_test_scores), axis=1)

# %%
plt.plot(svm_train_sizes, svm_train_scores_mean, 'o-', color="r",label="Training score")
plt.plot(svm_train_sizes, svm_test_scores_mean, 'o-', color="g",label="Cross-validation score")
plt.xlabel("Train size")
plt.ylabel("RMSE")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# Clearly a case of underfitting

# %% [markdown]
# <strong> PERFORMING AND MODEL'S PARAMETERS OPTIMIZATION.</strong>

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge()
ridge_reg.fit(X_train_prepared, y_train)
# Out:
# Ridge()

# %%
y_train_pred = ridge_reg.predict(X_train_prepared)
ridge_mse = mean_squared_error(y_train, y_train_pred)
ridge_rmse = np.sqrt(ridge_mse)
ridge_rmse
# Out:
# np.float64(22723.879851742244)

# %%
ridge_scores = cross_val_score(ridge_reg, X_train_prepared, y_train, scoring="neg_mean_squared_error", cv=5)
ridge_rmse_scores = np.sqrt(-ridge_scores)
display_scores(ridge_rmse_scores)
# Out:
# Scores: [23442.13993237 33531.36865065 31484.37076447 24979.59243806
#  45373.22673124]
# Mean: 31762.13970336023
# Standard deviation: 7793.51474403328

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso()
lasso_reg.fit(X_train_prepared, y_train)
# Out:
# c:\Users\T490s Ha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6392676414.542603, tolerance: 920791133.4609975
#   model = cd_fast.sparse_enet_coordinate_descent(
# Lasso()

# %%
y_train_pred = lasso_reg.predict(X_train_prepared)
lasso_mse = mean_squared_error(y_train, y_train_pred)
lasso_rmse = np.sqrt(lasso_mse)
lasso_rmse
# Out:
# np.float64(20949.898601952027)

# %%
lasso_scores = cross_val_score(lasso_reg, X_train_prepared, y_train, scoring="neg_mean_squared_error", cv=5)
lasso_rmse_scores = np.sqrt(-lasso_scores)
display_scores(lasso_rmse_scores)
# Out:
# c:\Users\T490s Ha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20776316215.00403, tolerance: 759214014.2531197
#   model = cd_fast.sparse_enet_coordinate_descent(
# c:\Users\T490s Ha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10583698022.392212, tolerance: 699031751.5199751
#   model = cd_fast.sparse_enet_coordinate_descent(
# Scores: [24265.4652737  34106.3477236  37333.55682431 23704.35306659
#  46319.93025489]
# Mean: 33145.93062862013
# Standard deviation: 8485.504488053828
# ...

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [100, 300, 500],
    'max_depth': [10, 20, None],
    'max_features': ['sqrt', 'log2'],
}

# %%
gri_search = GridSearchCV(RandomForestRegressor(random_state=42), param_grid, cv=5, scoring='neg_mean_squared_error', return_train_score=True)

# %%
gri_search.fit(X_train_prepared, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#              param_grid={'max_depth': [10, 20, None],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [100, 300, 500]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
forest_reg_best = gri_search.best_estimator_

# %%
sc=gri_search.best_score_
np.sqrt(-sc)
# Out:
# np.float64(30355.6353236335)

# %%
param_grid = {
    'C': [1, 10, 100],
    'epsilon': [0.01, 0.1, 0.5],
    'kernel': ['linear', 'rbf', 'poly']
}
gri_search=GridSearchCV(SVR(), param_grid, cv=5, scoring='neg_mean_squared_error', return_train_score=True)
gri_search.fit(X_train_prepared, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [1, 10, 100], 'epsilon': [0.01, 0.1, 0.5],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
svm_reg_best = gri_search.best_estimator_

# %%
sc=gri_search.best_score_
np.sqrt(-sc)
# Out:
# np.float64(34457.12699194517)

# %%
y_train_pred = svm_reg_best.predict(X_train_prepared)
svm_mse = mean_squared_error(y_train, y_train_pred)
svm_rmse = np.sqrt(svm_mse)
svm_rmse
# Out:
# np.float64(33013.08639111335)

# %% [markdown]
# <strong>Stacking</strong>

# %%
from sklearn.ensemble import VotingRegressor
voting_reg = VotingRegressor(estimators=[ ('rf', forest_reg_best), ('svr', svm_reg_best)])
voting_reg.fit(X_train_prepared, y_train)
# Out:
# VotingRegressor(estimators=[('rf',
#                              RandomForestRegressor(max_depth=20,
#                                                    max_features='sqrt',
#                                                    n_estimators=300,
#                                                    random_state=42)),
#                             ('svr', SVR(C=100, epsilon=0.5, kernel='linear'))])

# %%
y_train_pred = voting_reg.predict(X_train_prepared)
voting_mse = mean_squared_error(y_train, y_train_pred)
voting_rmse = np.sqrt(voting_mse)
voting_rmse
# Out:
# np.float64(21503.139887430163)

# %%
scores = cross_val_score(voting_reg, X_train_prepared, y_train, scoring="neg_mean_squared_error", cv=5)
voting_rmse_scores = np.sqrt(-scores)
display_scores(voting_rmse_scores)
# Out:
# Scores: [24080.53397054 31641.72942433 35057.25649479 24116.78976218
#  38850.68861678]
# Mean: 30749.399653723383
# Standard deviation: 5889.822566416297

# %%
from sklearn.ensemble import StackingRegressor
estimators = [
    ('rf', forest_reg_best),
    ('svr', svm_reg_best)
]
stacking_reg = StackingRegressor(estimators=estimators, final_estimator=ridge_reg)

# %%
stacking_reg.fit(X_train_prepared, y_train)
# Out:
# StackingRegressor(estimators=[('rf',
#                                RandomForestRegressor(max_depth=20,
#                                                      max_features='sqrt',
#                                                      n_estimators=300,
#                                                      random_state=42)),
#                               ('svr',
#                                SVR(C=100, epsilon=0.5, kernel='linear'))],
#                   final_estimator=Ridge())

# %%
y_train_pred = stacking_reg.predict(X_train_prepared)
stacking_mse = mean_squared_error(y_train, y_train_pred)
stacking_rmse = np.sqrt(stacking_mse)
stacking_rmse
# Out:
# np.float64(12262.157480592688)

# %%
scores = cross_val_score(stacking_reg, X_train_prepared, y_train, scoring="neg_mean_squared_error", cv=5)
stacking_rmse_scores = np.sqrt(-scores)
display_scores(stacking_rmse_scores)
# Out:
# Scores: [22823.559673   32582.45958241 30307.47670043 22206.62622693
#  37981.56050493]
# Mean: 29180.336537541334
# Standard deviation: 5989.118083411508

# %% [markdown]
# <strong>Test data</strong>

# %%
x_test = data_test.set_index('Id')
x_test_prepared = num_cat_pipeline.transform(x_test)
# Out:
# C:\Users\T490s Ha\AppData\Local\Temp\ipykernel_2708\3511087348.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X["FireplaceQu"].fillna("unknow", inplace=True)

# %%
y_test_pred = stacking_reg.predict(x_test_prepared)

# %%
final=pd.DataFrame()
final["Id"]=x_test.index
final["SalePrice"]=y_test_pred
final.to_csv("submission.csv", index=False)
